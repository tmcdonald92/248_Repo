# %%
import pandas
import pymysql
from sqlalchemy import create_engine
pd = pandas

# %%
username='root'
password='martin'
server='localhost'
database='finance'

# %%
engine = create_engine(f'mysql+pymysql://{username}:{password}@{server}/{database}')

# %%
query = """SELECT district_id, avg(amount) as amount FROM order
        GROUP BY district_id"""

# %%
df = pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\default.py in do_execute_no_params(self, cursor, statement, context)
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#
# ...

# %%
url='https://studio.ironhack.school/asset-v1:IRONHACK+DAFT+202006_PAR+type@asset+block@datasets_674388_1186156_tv_shows.csv'

# %%
df = pd.read_csv(url, index_col = 'Unnamed: 0')
df
# Out:
#                                 Title  Year  Age  IMDb Rotten Tomatoes  \
# 0                        Breaking Bad  2008  18+   9.5             96%
# 1                     Stranger Things  2016  16+   8.8             93%
# 2                         Money Heist  2017  18+   8.4             91%
# 3                            Sherlock  2010  16+   9.1             78%
# 4                    Better Call Saul  2015  18+   8.7             97%
# ...                               ...   ...  ...   ...             ...
# 5606  Tut's Treasures: Hidden Secrets  2018  NaN   NaN             NaN
# 5607                 Paradise Islands  2017  NaN   NaN             NaN
# 5608                      Wild Russia  2018  NaN   NaN             NaN
# 5609                      Love & Vets  2017  NaN   NaN             NaN
# 5610         United States of Animals  2016  NaN   NaN             NaN
#
#       Netflix  Hulu  Prime Video  Disney+  type
# 0           1     0            0        0     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5611 entries, 0 to 5610
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            5611 non-null   object
#  1   Year             5611 non-null   int64
#  2   Age              3165 non-null   object
#  3   IMDb             4450 non-null   float64
#  4   Rotten Tomatoes  1011 non-null   object
#  5   Netflix          5611 non-null   int64
#  6   Hulu             5611 non-null   int64
#  7   Prime Video      5611 non-null   int64
#  8   Disney+          5611 non-null   int64
#  9   type             5611 non-null   int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 416.4+ KB

# %%
df.loc[df.IMDb>9.2, 'todolist'] = 'to watch'
df
# Out:
#                                 Title  Year  Age  IMDb Rotten Tomatoes  \
# 0                        Breaking Bad  2008  18+   9.5             96%
# 1                     Stranger Things  2016  16+   8.8             93%
# 2                         Money Heist  2017  18+   8.4             91%
# 3                            Sherlock  2010  16+   9.1             78%
# 4                    Better Call Saul  2015  18+   8.7             97%
# ...                               ...   ...  ...   ...             ...
# 5606  Tut's Treasures: Hidden Secrets  2018  NaN   NaN             NaN
# 5607                 Paradise Islands  2017  NaN   NaN             NaN
# 5608                      Wild Russia  2018  NaN   NaN             NaN
# 5609                      Love & Vets  2017  NaN   NaN             NaN
# 5610         United States of Animals  2016  NaN   NaN             NaN
#
#       Netflix  Hulu  Prime Video  Disney+  type  todolist
# ...

# %%
df.loc[~(df.IMDb>9.2), 'todolist'] = 'skip'
df
# Out:
#                                 Title  Year  Age  IMDb Rotten Tomatoes  \
# 0                        Breaking Bad  2008  18+   9.5             96%
# 1                     Stranger Things  2016  16+   8.8             93%
# 2                         Money Heist  2017  18+   8.4             91%
# 3                            Sherlock  2010  16+   9.1             78%
# 4                    Better Call Saul  2015  18+   8.7             97%
# ...                               ...   ...  ...   ...             ...
# 5606  Tut's Treasures: Hidden Secrets  2018  NaN   NaN             NaN
# 5607                 Paradise Islands  2017  NaN   NaN             NaN
# 5608                      Wild Russia  2018  NaN   NaN             NaN
# 5609                      Love & Vets  2017  NaN   NaN             NaN
# 5610         United States of Animals  2016  NaN   NaN             NaN
#
#       Netflix  Hulu  Prime Video  Disney+  type  todolist
# ...

# %% [markdown]
# Unique Values

# %%
df.nunique()
# Out:
# Title              5564
# Year                 81
# Age                   5
# IMDb                 78
# Rotten Tomatoes      88
# Netflix               2
# Hulu                  2
# Prime Video           2
# Disney+               2
# type                  1
# todolist              2
# dtype: int64

# %%
# Returns the unique values
df.Age.unique()
# Out:
# array(['18+', '16+', '7+', nan, 'all', '13+'], dtype=object)

# %%
# Returns the number of unique values
df.Age.nunique()
# Out:
# 5

# %%
# Returns the frequency of each value
df.Age.value_counts()
# Out:
# 16+    1018
# 7+      848
# 18+     750
# all     545
# 13+       4
# Name: Age, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5611 entries, 0 to 5610
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            5611 non-null   object
#  1   Year             5611 non-null   int64
#  2   Age              3165 non-null   object
#  3   IMDb             4450 non-null   float64
#  4   Rotten Tomatoes  1011 non-null   object
#  5   Netflix          5611 non-null   int64
#  6   Hulu             5611 non-null   int64
#  7   Prime Video      5611 non-null   int64
#  8   Disney+          5611 non-null   int64
#  9   type             5611 non-null   int64
#  10  todolist         5611 non-null   object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 438.4+ KB
