# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Doctolib" data-toc-modified-id="Doctolib-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Doctolib</a></span></li><li><span><a href="#Twitch" data-toc-modified-id="Twitch-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Twitch</a></span></li></ul></div>

# %% [markdown]
# # Doctolib

# %%
url='https://www.doctolib.fr/ophtalmologue/france?page=2'

# %%
import requests as r

# %%
headers="""accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
accept-encoding: gzip, deflate, br
accept-language: en-US,en;q=0.9
cache-control: no-cache
cookie: __cfduid=dbf7716adff9836528239df025cda5b671599571100; ssid=c850418384lin-9KBaeo8FS6ZH; esid=RW02h783zv-oLrANp9UaDjZU; cookie_consent=true; didomi_token=eyJ1c2VyX2lkIjoiMTc0NmRkZTAtOGI4Mi02YTVjLWExY2YtOGYxYzVhOGM0ZWE3IiwiY3JlYXRlZCI6IjIwMjAtMDktMDhUMTM6MTg6MjEuOTA4WiIsInVwZGF0ZWQiOiIyMDIwLTA5LTA4VDEzOjE4OjIxLjkwOVoiLCJ2ZXJzaW9uIjpudWxsfQ==; utm_b2b=eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaEpJaUoxZEcxZmMyOTFjbU5sUFdScGNtVmpkQ1oxZEcxZmJXVmthWFZ0UFFZNkJrVlUiLCJleHAiOiIyMDIwLTA5LTA4VDEzOjQ5OjAyLjMwMFoiLCJwdXIiOiJjb29raWUudXRtX2IyYiJ9fQ%3D%3D--e58c0978ac636918d55e052199debc1c0f3b8864; _doctolib_session=jjvBpfxuPN2lY%2F2r3cO4DlPJ9COkcfkdG1uTEOuIUFTwma2oGh3SNGIR7iK283RhiO0WeNrHrtDE1zWRt4pgLYis%2BY9hpxWIMF1zkkmEgz%2BlMtXko%2BgVDo3%2F8APP1TcuNgGFRYJ37Tqe7taQ4L7j%2Fs463ld06xk9CHgUhHWw6gyb9OW5qXow7DIEPQEzkPEhTxcfFa6Jl%2BxPoqr5qCAbmsrsH3e%2F0O%2FbHL1gNloYpGByh%2BIHyNIAeKNFc36xRzGu6eSAMD%2FWtnPsbf9LQEFYZrmpxv36mWQQw15ECs0F912TJbNEmtPf99no8dTII%2BK3DpVFFmFNgdFO1UtZa5bjJ%2BZof3zLoEitZw%3D%3D--vymRb89pliHr3tqg--XHYr2qg%2Bi0V%2FXlZGtDoIfA%3D%3D
pragma: no-cache
referer: https://www.doctolib.fr/ophtalmologue/france
upgrade-insecure-requests: 1
user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.84 Safari/537.36"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
resp=r.get(url, headers=headers)

# %%
resp.content
# Out:
# b'c\x00\xf8\xff\x13EE\xad\x87f\xa4&\xf5\x00h\xa4,\x9c\xbf\x7f\x06\x8e\xeb\xb1\xce\xfb/M}{6\xd53~\x12R\x11\xf6qO,@\x19\xf2\xe8\xb8\x1c\xca\x07}\\\xf3\x87\xb3\x04\x16$\xe4%\x16\x1f\x0bP\x87\xad\x99tU&*\xca\xd4\xaa\xba\xfc\x99?\xab\xfb\\N)U\xf5i\xc8\xc4\x7f\x0c\xf3\x95\xe5g\xac\x8e,)\x92\x0c\xa1{S*\x07\xdc\xe0\x8e\xb1Yl\xc30\x9f\xe3a/\xe7\xfd\xff\xfdi\xd9\xa2&\x00\\\x02\x96\x00\xd4\x027\xd5\xcc\x85\xf7\xe3O\xca\xf9\xd2\xb7\xcf~C&_\xf6\xfaDc\xcf\xeeJ\xf6\x82<3y\xef\xbe\xe7YIK\xb6\x975\x81]\x1e\nx7\x84\n V)\xb1G.\x11\x9bj\xb1J:\x82\n\xb1\xccc\xb4\xfc\xca\xa5\x89\x80\x08|\xb8\xdbchv\x1d+\xf1\xd2\x9f@\xd1\xb0\xb5\xf31\xd4znv\xdf\x8a\xa8\x04q\x01\xe6k2f\x16\x7fMWX!\x0c-\x9c\xb6.J\x00\xe2\xff\x88s\xef\x97s\xb1\xd6\xf4\xe0\x87\x0e\xd2n\x04\xafF\'~ka\xf9\xf8J\x06\xf2\'\x1d4\xa0K\x0c\xb7v\xdcY\xd8\xd4Tj\x80\xd9\xdeh\xd3\xf7m\'cJ\x878a\xc3\x86\xae^a\xd5\x11rH\x15 \xc2\xfd\xf2\xa8\xea\xa2m\xc5\x9a\x12\xba\x93\xf7\x86\xe4\xc1}\x1c\xddgl\xb3\xcb\xa3v\xd5\xd5\xbe\x89\x0e_\xbe\x94$\x82\x01f\xcfy4\xf4\
# ...

# %%
headers=f"""accept: application/json
    accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
    cache-control: no-cache
    content-type: application/json; charset=utf-8
    cookie: __cfduid=dbf7716adff9836528239df025cda5b671599571100; ssid=c850418384lin-9KBaeo8FS6ZH; esid=RW02h783zv-oLrANp9UaDjZU; cookie_consent=true; didomi_token=eyJ1c2VyX2lkIjoiMTc0NmRkZTAtOGI4Mi02YTVjLWExY2YtOGYxYzVhOGM0ZWE3IiwiY3JlYXRlZCI6IjIwMjAtMDktMDhUMTM6MTg6MjEuOTA4WiIsInVwZGF0ZWQiOiIyMDIwLTA5LTA4VDEzOjE4OjIxLjkwOVoiLCJ2ZXJzaW9uIjpudWxsfQ==; utm_b2b=eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaEpJaUoxZEcxZmMyOTFjbU5sUFdScGNtVmpkQ1oxZEcxZmJXVmthWFZ0UFFZNkJrVlUiLCJleHAiOiIyMDIwLTA5LTA4VDEzOjQ5OjAyLjMwMFoiLCJwdXIiOiJjb29raWUudXRtX2IyYiJ9fQ%3D%3D--e58c0978ac636918d55e052199debc1c0f3b8864; _doctolib_session=jjvBpfxuPN2lY%2F2r3cO4DlPJ9COkcfkdG1uTEOuIUFTwma2oGh3SNGIR7iK283RhiO0WeNrHrtDE1zWRt4pgLYis%2BY9hpxWIMF1zkkmEgz%2BlMtXko%2BgVDo3%2F8APP1TcuNgGFRYJ37Tqe7taQ4L7j%2Fs463ld06xk9CHgUhHWw6gyb9OW5qXow7DIEPQEzkPEhTxcfFa6Jl%2BxPoqr5qCAbmsrsH3e%2F0O%2FbHL1gNloYpGByh%2BIHyNIAeKNFc36xRzGu6eSAMD%2FWtnPsbf9LQEFYZrmpxv36mWQQw15ECs0F912TJbNEmtPf99no8dTII%2BK3DpVFFmFNgdFO1UtZa5bjJ%2BZof3zLoEitZw%3D%3D--vymRb89pliHr3tqg--XHYr2qg%2Bi0V%2FXlZGtDoIfA%3D%3D
    referer: https://www.doctolib.fr/ophtalmologue/france?page=2
    user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.84 Safari/537.36
    x-csrf-token: 0TdGUM30Z1AsWwbDAcnhqX8oBJNFnYO4ChJJna6v89Op3FVpLe67uaR1QeMITcssVT1+WT2PAL8D1h0y+5uY6g=="""
headers=dict([i.strip().split(': ') for i in headers.split('\n')])

# %%
r.get(url, headers=headers).json()
# Out:
# {'data': {'speciality': {'id': 4,
#    'name': 'Ophtalmologue',
#    'slug': 'ophtalmologue',
#    'search_results_priority': False,
#    'telehealth_core': False},
#   'doctors': [{'id': 2740594,
#     'is_directory': False,
#     'address': '12 Avenue Jean Moulin',
#     'city': 'Lalinde',
#     'zipcode': '24150',
#     'link': '/ophtalmologue/lalinde/aurora-cristea',
#     'cloudinary_public_id': 'pwecu4fmsx28qoikkqz3',
#     'profile_id': 19979,
#     'exact_match': True,
#     'priority_speciality': False,
#     'first_name': 'Aurora',
#     'last_name': 'Cristea',
#     'name_with_title': 'Dr Aurora Cristea',
#     'speciality': 'Ophtalmologue',
#     'organization_status': None,
#     'position': {'lat': 44.8351554, 'lng': 0.724624700000049},
#     'place_id': None,
#     'telehealth': False},
#    {'id': 3012079,
#     'is_directory': False,
#     'address': '5 Allée de la Mandallaz',
#     'city': 'Metz-Tessy',
#     'zipcode': '74370',
# ...

# %% [markdown]
# # Twitch

# %%
url='https://gql.twitch.tv/gql'

# %%
headers="""Accept: */*
Accept-Encoding: gzip, deflate, br
Accept-Language: en-US
Cache-Control: no-cache
Client-Id: kimne78kx3ncx6brgo4mv6wki5h1ko
Connection: keep-alive
Content-Length: 6488
Content-Type: text/plain;charset=UTF-8
Host: gql.twitch.tv
Origin: https://www.twitch.tv
Pragma: no-cache
Referer: https://www.twitch.tv/lestream
Sec-Fetch-Dest: empty
Sec-Fetch-Mode: cors
Sec-Fetch-Site: same-site
User-Agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.84 Safari/537.36
X-Device-Id: 7b868d198ea044f8"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
payload="""[{"operationName":"Consent","variables":{"id":"338f3f39-5bac-4dea-9cc3-1c0b174170b6"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"846f36c838ab34e93439795791626fb6a3014b03dd0e4ac1fed681822181021a"}}},{"operationName":"Ads_Components_AdManager_User","variables":{},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"1fd9eeac7ab98004ee00dc6554e88759f1fa66ea94b97487f69b1ddf3a9d215b"}}},{"operationName":"TopNav_CurrentUser","variables":{},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"625a9b3015d5956f18a813ecb7619bcbdccd037cdafcb64c31c2f98c009e71b5"}}},{"operationName":"Prime_PrimeOffers_CurrentUser","variables":{},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"a773b7efefe390d49753520f7db73d03794b008af6acc22c06a2c630d46d5518"}}},{"operationName":"PersonalSections","variables":{"input":{"sectionInputs":["RECOMMENDED_SECTION"],"recommendationContext":{"platform":"web"}},"channelLogin":null,"withChannelUser":false},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"469efc9442aa2b7634a3ab36eae1778b78ec7ccf062d2b17833afb0e66b78a25"}}},{"operationName":"ChannelShell","variables":{"login":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2b29e2150fe65ee346e03bd417bbabbd0471a01a84edb7a74e3c6064b0283287"}}},{"operationName":"UseLive","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"639d5f11bfb8bf3053b424d9ef650d04c4ebb7d94711d644afb08fe9a0fad5d9"}}},{"operationName":"ActiveWatchParty","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"4a8156c97b19e3a36e081cf6d6ddb5dbf9f9b02ae60e4d2ff26ed70aebc80a30"}}},{"operationName":"UseHosting","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"427f55a3daca510f726c02695a898ef3a0de4355b39af328848876052ea6b337"}}},{"operationName":"DropCurrentSessionContext","variables":{},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2e4b3630b91552eb05b76a94b6850eb25fe42263b7cf6d06bee6d156dd247c1c"}}},{"operationName":"PersonalSections","variables":{"input":{"sectionInputs":["RECOMMENDED_SECTION","SIMILAR_SECTION"],"recommendationContext":{"platform":"web"},"contextChannelName":"lestream"},"channelLogin":"lestream","withChannelUser":true},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"469efc9442aa2b7634a3ab36eae1778b78ec7ccf062d2b17833afb0e66b78a25"}}},{"operationName":"PlayerTrackingContextQuery","variables":{"channel":"lestream","isLive":true,"hasCollection":false,"collectionID":"","videoID":"","hasVideo":false,"slug":"","hasClip":false},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"3fbf508886ff5e008cb94047acc752aad7428c07b6055995604de16c4b01160a"}}},{"operationName":"ExtensionsUIContext_ChannelID","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"aaa9870965b55ecb88e01a4d73b5427e8ff9397eea16b9adbd08cad86d3b9d25"}}},{"operationName":"ExtensionsForChannelCurrentUser","variables":{"channelID":""},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"cd794415959dcdc575179b808647aaef0abdfe5e3aaf70d5f3ffbca43209dc3c"}}},{"operationName":"VideoPreviewOverlay","variables":{"login":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"3006e77e51b128d838fa4e835723ca4dc9a05c5efd4466c1085215c6e437e65c"}}},{"operationName":"VideoAdBanner","variables":{"input":{"login":"lestream","ownsCollectionID":"","ownsVideoID":""}},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"33c38317fd1d2ca11dfd51ca241e7670eb55382c3cf435230ff244e6cd6af391"}}},{"operationName":"VideoPlayer_SubToSkipAds","variables":{"login":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"fc2dffb83a22adf1030eea340c680a7698d705c7dd31fdb2dd39c07ad05e27e3"}}},{"operationName":"ExtensionsOverlay_ChannelGame","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2a7c2676c902e1243ebdc34172f1b3a76ff4aad0a67dfd168cf5fa86b03d66dc"}}},{"operationName":"MatureGateOverlayBroadcaster","variables":{"input":{"login":"lestream","ownsVideoID":null}},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"db5c4f54238cb6cde9d1ab49dab9d6388bb4990304766fcd70c1f37d4ed93bdb"}}},{"operationName":"VideoPlayer_AgeGateOverlayBroadcaster","variables":{"input":{"login":"lestream","ownsVideoID":null}},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"ab175a77fb908cd5dfe25d6d23da0765b3fc187e3d3461d1c7b157c354e917ee"}}},{"operationName":"CountessData","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2243fa4daedcf4607ddcb95bb6cda7bb4c7421f6fde66fbd824702b4922c0e76"}}},{"operationName":"VideoPlayer_VideoSourceManager","variables":{"input":{"login":"lestream","ownsVideoID":null,"ownsCollectionID":null,"broadcasterOfClipSlug":null}},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"f5e1b35d6f5a40348c6476fea36945d0931ba50621e1701b6c31252ee498cc3e"}}},{"operationName":"StreamTagsTrackingChannel","variables":{"channel":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"327d7b1596b37898de6a0eaabfdd8ee37b6cc586daab0d12b8fad64f03856a4a"}}},{"operationName":"ComscoreStreamingQuery","variables":{"channel":"lestream","clipSlug":"","isClip":false,"isLive":true,"isVodOrCollection":false,"vodID":""},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"e1edae8122517d013405f237ffcc124515dc6ded82480a88daef69c83b53ac01"}}},{"operationName":"StreamRefetchManager","variables":{"channel":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"9cf8a0947dd0ec469d31e8d3b2bd3d9ae5590a6e4b441b6c92f61f28382811de"}}},{"operationName":"VideoAdRequestHandling","variables":{"isLive":true,"login":"lestream","isVOD":false,"vodID":"","isCollection":false,"collectionID":""},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"4afa569067d6d37579e2d08f39fdf28db340572a6a7924c8523ec2cb5707ac23"}}},{"operationName":"NielsenContentMetadata","variables":{"isCollectionContent":false,"isLiveContent":true,"isVODContent":false,"collectionID":"","login":"lestream","vodID":""},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2dbf505ee929438369e68e72319d1106bb3c142e295332fac157c90638968586"}}},{"operationName":"VideoPlayerStreamMetadata","variables":{"channel":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"248fee6868e983c4e7b69074e888960f77735bd21a1d4a1d882b55f45d30a420"}}}]"""

# %%
resp=r.post(url, headers=headers, data=payload).json()

# %%
resp[4]['data']['personalSections'][0]['items'][1]['content']['viewersCount']
# Out:
# 3354

# %%
resp[4]['data']['personalSections'][0]['items'][1]['content']['viewersCount']
# Out:
# 3282

# %%
len(resp)
# Out:
# 28

# %%
import json
json.loads("""
[{"operationName":"Consent","variables":{"id":"338f3f39-5bac-4dea-9cc3-1c0b174170b6"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"846f36c838ab34e93439795791626fb6a3014b03dd0e4ac1fed681822181021a"}}},{"operationName":"Ads_Components_AdManager_User","variables":{},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"1fd9eeac7ab98004ee00dc6554e88759f1fa66ea94b97487f69b1ddf3a9d215b"}}},{"operationName":"TopNav_CurrentUser","variables":{},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"625a9b3015d5956f18a813ecb7619bcbdccd037cdafcb64c31c2f98c009e71b5"}}},{"operationName":"Prime_PrimeOffers_CurrentUser","variables":{},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"a773b7efefe390d49753520f7db73d03794b008af6acc22c06a2c630d46d5518"}}},{"operationName":"PersonalSections","variables":{"input":{"sectionInputs":["RECOMMENDED_SECTION"],"recommendationContext":{"platform":"web"}},"channelLogin":null,"withChannelUser":false},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"469efc9442aa2b7634a3ab36eae1778b78ec7ccf062d2b17833afb0e66b78a25"}}},{"operationName":"ChannelShell","variables":{"login":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2b29e2150fe65ee346e03bd417bbabbd0471a01a84edb7a74e3c6064b0283287"}}},{"operationName":"UseLive","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"639d5f11bfb8bf3053b424d9ef650d04c4ebb7d94711d644afb08fe9a0fad5d9"}}},{"operationName":"ActiveWatchParty","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"4a8156c97b19e3a36e081cf6d6ddb5dbf9f9b02ae60e4d2ff26ed70aebc80a30"}}},{"operationName":"UseHosting","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"427f55a3daca510f726c02695a898ef3a0de4355b39af328848876052ea6b337"}}},{"operationName":"DropCurrentSessionContext","variables":{},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2e4b3630b91552eb05b76a94b6850eb25fe42263b7cf6d06bee6d156dd247c1c"}}},{"operationName":"PersonalSections","variables":{"input":{"sectionInputs":["RECOMMENDED_SECTION","SIMILAR_SECTION"],"recommendationContext":{"platform":"web"},"contextChannelName":"lestream"},"channelLogin":"lestream","withChannelUser":true},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"469efc9442aa2b7634a3ab36eae1778b78ec7ccf062d2b17833afb0e66b78a25"}}},{"operationName":"PlayerTrackingContextQuery","variables":{"channel":"lestream","isLive":true,"hasCollection":false,"collectionID":"","videoID":"","hasVideo":false,"slug":"","hasClip":false},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"3fbf508886ff5e008cb94047acc752aad7428c07b6055995604de16c4b01160a"}}},{"operationName":"ExtensionsUIContext_ChannelID","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"aaa9870965b55ecb88e01a4d73b5427e8ff9397eea16b9adbd08cad86d3b9d25"}}},{"operationName":"ExtensionsForChannelCurrentUser","variables":{"channelID":""},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"cd794415959dcdc575179b808647aaef0abdfe5e3aaf70d5f3ffbca43209dc3c"}}},{"operationName":"VideoPreviewOverlay","variables":{"login":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"3006e77e51b128d838fa4e835723ca4dc9a05c5efd4466c1085215c6e437e65c"}}},{"operationName":"VideoAdBanner","variables":{"input":{"login":"lestream","ownsCollectionID":"","ownsVideoID":""}},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"33c38317fd1d2ca11dfd51ca241e7670eb55382c3cf435230ff244e6cd6af391"}}},{"operationName":"VideoPlayer_SubToSkipAds","variables":{"login":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"fc2dffb83a22adf1030eea340c680a7698d705c7dd31fdb2dd39c07ad05e27e3"}}},{"operationName":"ExtensionsOverlay_ChannelGame","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2a7c2676c902e1243ebdc34172f1b3a76ff4aad0a67dfd168cf5fa86b03d66dc"}}},{"operationName":"MatureGateOverlayBroadcaster","variables":{"input":{"login":"lestream","ownsVideoID":null}},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"db5c4f54238cb6cde9d1ab49dab9d6388bb4990304766fcd70c1f37d4ed93bdb"}}},{"operationName":"VideoPlayer_AgeGateOverlayBroadcaster","variables":{"input":{"login":"lestream","ownsVideoID":null}},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"ab175a77fb908cd5dfe25d6d23da0765b3fc187e3d3461d1c7b157c354e917ee"}}},{"operationName":"CountessData","variables":{"channelLogin":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2243fa4daedcf4607ddcb95bb6cda7bb4c7421f6fde66fbd824702b4922c0e76"}}},{"operationName":"VideoPlayer_VideoSourceManager","variables":{"input":{"login":"lestream","ownsVideoID":null,"ownsCollectionID":null,"broadcasterOfClipSlug":null}},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"f5e1b35d6f5a40348c6476fea36945d0931ba50621e1701b6c31252ee498cc3e"}}},{"operationName":"StreamTagsTrackingChannel","variables":{"channel":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"327d7b1596b37898de6a0eaabfdd8ee37b6cc586daab0d12b8fad64f03856a4a"}}},{"operationName":"ComscoreStreamingQuery","variables":{"channel":"lestream","clipSlug":"","isClip":false,"isLive":true,"isVodOrCollection":false,"vodID":""},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"e1edae8122517d013405f237ffcc124515dc6ded82480a88daef69c83b53ac01"}}},{"operationName":"StreamRefetchManager","variables":{"channel":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"9cf8a0947dd0ec469d31e8d3b2bd3d9ae5590a6e4b441b6c92f61f28382811de"}}},{"operationName":"VideoAdRequestHandling","variables":{"isLive":true,"login":"lestream","isVOD":false,"vodID":"","isCollection":false,"collectionID":""},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"4afa569067d6d37579e2d08f39fdf28db340572a6a7924c8523ec2cb5707ac23"}}},{"operationName":"NielsenContentMetadata","variables":{"isCollectionContent":false,"isLiveContent":true,"isVODContent":false,"collectionID":"","login":"lestream","vodID":""},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"2dbf505ee929438369e68e72319d1106bb3c142e295332fac157c90638968586"}}},{"operationName":"VideoPlayerStreamMetadata","variables":{"channel":"lestream"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"248fee6868e983c4e7b69074e888960f77735bd21a1d4a1d882b55f45d30a420"}}}]
""")
# Out:
# [{'operationName': 'Consent',
#   'variables': {'id': '338f3f39-5bac-4dea-9cc3-1c0b174170b6'},
#   'extensions': {'persistedQuery': {'version': 1,
#     'sha256Hash': '846f36c838ab34e93439795791626fb6a3014b03dd0e4ac1fed681822181021a'}}},
#  {'operationName': 'Ads_Components_AdManager_User',
#   'variables': {},
#   'extensions': {'persistedQuery': {'version': 1,
#     'sha256Hash': '1fd9eeac7ab98004ee00dc6554e88759f1fa66ea94b97487f69b1ddf3a9d215b'}}},
#  {'operationName': 'TopNav_CurrentUser',
#   'variables': {},
#   'extensions': {'persistedQuery': {'version': 1,
#     'sha256Hash': '625a9b3015d5956f18a813ecb7619bcbdccd037cdafcb64c31c2f98c009e71b5'}}},
#  {'operationName': 'Prime_PrimeOffers_CurrentUser',
#   'variables': {},
#   'extensions': {'persistedQuery': {'version': 1,
#     'sha256Hash': 'a773b7efefe390d49753520f7db73d03794b008af6acc22c06a2c630d46d5518'}}},
#  {'operationName': 'PersonalSections',
#   'variables': {'input': {'sectionInputs': ['RECOMMENDED_SECTION'],
# ...

# %%
payload="""{"operationName":"PersonalSections","variables":{"input":{"sectionInputs":["RECOMMENDED_SECTION"],"recommendationContext":{"platform":"web"}},"channelLogin":null,"withChannelUser":false},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"469efc9442aa2b7634a3ab36eae1778b78ec7ccf062d2b17833afb0e66b78a25"}}}"""

# %%
resp=r.post(url, headers=headers, data=payload).json()

# %%
resp['data']['personalSections'][0]['items'][1]['content']['viewersCount']
# Out:
# 3354

# %%
url='https://www.yst.am/browse-movies?page=2'

# %%
headers="""accept: */*
accept-encoding: gzip, deflate, br
accept-language: en-US,en;q=0.9
cache-control: no-cache
cookie: __cfduid=da2c0d17748c05e79e21e442d1b3c13df1599579712
pragma: no-cache
referer: https://www.yst.am/browse-movies?page=2
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.84 Safari/537.36
x-requested-with: XMLHttpRequest
x-csrf-token: 9676a3f0996b86e868ae49f4fe8694cee002abb045cb386b05a9800731d5324b"""

# %%
payload="""{"tag":"recettes-express"}"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
pd.read_html(r.get(url).content)[2]
# Out:
#                                           Restaurants     [ Edit ]  \
# 0                        Meal, Inexpensive Restaurant     10.00 RM
# 1   Meal for 2 People, Mid-range Restaurant, Three...     60.00 RM
# 2      McMeal at McDonalds (or Equivalent Combo Meal)     15.00 RM
# 3                   Domestic Beer (0.5 liter draught)     15.00 RM
# 4                   Imported Beer (0.33 liter bottle)     16.00 RM
# ..                                                ...          ...
# 59  Price per Square Meter to Buy Apartment in Cit...  8,884.10 RM
# 60  Price per Square Meter to Buy Apartment Outsid...  5,068.47 RM
# 61                             Salaries And Financing     [ Edit ]
# 62             Average Monthly Net Salary (After Tax)  3,575.67 RM
# 63  Mortgage Interest Rate in Percentages (%), Yea...         4.43
#
#                Range
# 0         5.70-20.00
# 1       40.00-150.00
# 2        13.00-17.00
# 3         8.00-25.00
# 4        10.00-26.00
# ..               ...
# ...

# %%
r.get(url,params='9676a3f0996b86e868ae49f4fe8694cee002abb045cb386b05a9800731d5324b', headers=headers).content#, data=payload).json()).select('article.post a')
# Out:
# b'\x03%\x1cD\x14\xf3\x01P\x84\x0cs\xff\xed\xd5\xec;\x9e\xc9\xc7\xff\x0bi\xceDX\xa84\xdf\x9a-=\xfdn}\xad \xe9I&\x8b@\x07\xc8+\xa7\xfc\xb5\xf4\xd5\xe9*)\x97\xd2\x19\xef\x9a \x8fQ\x00)\x1d\xa0\xefWv\x93\xdd\x93\xfe\xcc}\xc9Mr\x95K+{\xbb\xefN=\xb55\x1e@<\x01,\x00\xc6aA\x81H?\x1d\xc2l\xc3\xd9\xf1*\x954X\x9cul\xb6\x86zt.\x1b\x8c#H,\xbe]\x12#\xa0\xce\x17\xad\x06\x8d\xf4\xd8\rA]ABJM\xe8\xde\x9dB\x9e\n\xe2\x07\xe1\xf7\xdb\xab\xdf\xe1\xbd\xd9Kt\xb05\x96\xd0k\xd0b_\xe0\x80\xc2\xef\xdb;\xa0P\xb7\xdb@<\xe7Xz\x86GV\x14[o\xc8\xe4;Z\xe6\xf7\x95O(\xfdSvp{\xf97\x07\xb8_t\xe7\xfdH\xf1\xffI\xee7\xa4\x1a@\x8ek7\xe4\xf6rC\x0bq\xd0Z/\xb0\x89\x08\x87\xb3\xde8O\xa2\tE\xcc.\n\x9a&\xa3g\xd34I\x00\xbcu\xc0 \x14\x9dd\x00\x9dC\xc4\xb8q\x13\xadX@\xad\xa9\xcdx&\x07\xbeA/\xbc\xd0F\x1b\x02\x1d#hp\xd5`\xa9\xd6\xdcf\rg\xa8\xe4\xd9#\xdf\x18\xc0\xdd4\xa2\x85;/\xec\xeaZ\xa9\xd4!X\xfcq\xa8\x1b\x84\x17p!\xec\xbdF\xe7\x02\xd8\xee\x10\x88\xb6\x1bf\x05\x98\xc1x~\x9aA\xe85\xbc\x17\x1aL\x07[3\x18k\xcdC\x00\xef\xed\n~\x11\xc3(-\x
# ...
